# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayfalmayvandra/PraktikumBigData/blob/main/2410506009_MapReduce_BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict

def map_function(text):
  for word in text.split():
    yield (word.lower(), 1)

def reduce_function(pairs):
    result = defaultdict(int)
    for word, count in pairs:
        result[word] += count
    return result

text = "Hai nama saya Assep Azrul, saya suka dengerin sound horeg di malam hari"
map = list(map_function(text))
reduce = reduce_function(map)

for word, count in reduce.items():
    print(f"{word}: {count}")
# Out:
# hai: 1
# nama: 1
# saya: 2
# assep: 1
# azrul,: 1
# suka: 1
# dengerin: 1
# sound: 1
# horeg: 1
# di: 1
# malam: 1
# hari: 1
